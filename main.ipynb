# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from selenium import webdriver
from utilities.add_reverse_index import add_reverse_column
from utilities.fetch_website import fetch_website_with_selenium 
from utilities.clean_html import strip_html
from utilities.save_csv_today import save_data_csv
from utilities.analyse_headlines import save_sentiment_analysis_to_csv
from utilities.analyse_headlines import headline_analyser
# from utilities.sentiment_plot import plot_gradient_sentiment_line
from utilities.sentiment_plot import create_plot
from utilities.moving_averages import calculate_moving_averages

# %%
url = 'https://www.rte.ie/'  # Replace with the RTÉ page or any target page
to_remove_ids = ['embedWrapper', 'panel-podcasts-we-love', 'panel-best-of-rte-player']
to_remove_classes = ['panel-heading', 'head-row', 'row buttonbar']
tags_to_extract = ['h3', 'h5']

# Fetch the HTML using Selenium
html_content = fetch_website_with_selenium(url)

if html_content:
    extracted_content = strip_html(html_content, to_remove_ids, to_remove_classes, tags_to_extract)
    indexed_data = add_reverse_column(extracted_content)
    results_data = headline_analyser(indexed_data)

# %%
prepped_data = calculate_moving_averages(results_data)
create_plot(prepped_data)
# plot_gradient_sentiment(prepped_data)

# %%
prepped_data
# Out:
#           date                                           headline    neg  \
# 0   2024-10-17  SF proposal to replace Stanley on PAC to go be...  0.000
# 1   2024-10-17  One Direction singer Liam Payne dies in Argent...  0.000
# 2   2024-10-17                                               Live  0.000
# 3   2024-10-17  Man charged with murder of child among three d...  0.419
# 4   2024-10-17  Molloy back in Ireland squad, Keane gets first...  0.000
# ..         ...                                                ...    ...
# 65  2024-10-17  Boy may have been killed over two years ago - ...  0.310
# 66  2024-10-17  Postman given suspended sentence over stolen c...  0.543
# 67  2024-10-17       We and our partners process data to provide:  0.000
# 68  2024-10-17                         Manage Consent Preferences  0.000
# 69  2024-10-17                                        Cookie List  0.000
#
#       neu    pos  compound overall_sentiment  Index  scaled_compound  \
# 0   1.000  0.000    0.0000           Neutral      0         0.103851
# 1   1.000  0.000    0.0000           Neutral      1         0.103851
# 2   1.000  0.000    0.0000           Neutral      2         0.103851
# 3   0.581  0.000   -0.7579          Negative      3        -0.925694
# 4   1.000  0.000    0.0000           Neutral      4         0.103851
# ..    ...    ...       ...               ...    ...              ...
# 65  0.690  0.000   -0.6705          Negative     65        -0.806969
# 66  0.345  0.112   -0.7184          Negative     66        -0.872037
# 67  1.000  0.000    0.0000           Neutral     67         0.103851
# 68  0.513  0.487    0.2263          Positive     68         0.411261
# 69  1.000  0.000    0.0000           Neutral     69         0.103851
#
#     VADER_MA_03  VADER_MA_10  VADER_MA_20
# 0           NaN          NaN          NaN
# 1           NaN          NaN          NaN
# 2      0.103851          NaN          NaN
# 3     -0.239331          NaN          NaN
# 4     -0.239331          NaN          NaN
# ..          ...          ...          ...
# 65    -0.839118    -0.234298    -0.018969
# 66    -0.893002    -0.373711    -0.134930
# 67    -0.525052    -0.373711    -0.134930
# 68    -0.118975    -0.329795    -0.112972
# 69     0.206321    -0.395775    -0.112972
#
# [70 rows x 12 columns]
