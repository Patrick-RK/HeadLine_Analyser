# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from selenium import webdriver
from utilities.add_reverse_index import add_reverse_column
from utilities.fetch_website import fetch_website_with_selenium 
from utilities.clean_html import strip_html
from utilities.save_csv_today import save_data_csv
from utilities.analyse_headlines import save_sentiment_analysis_to_csv
from utilities.analyse_headlines import headline_analyser
from utilities.sentiment_plot import plot_sentiment_analysis

# %%
url = 'https://www.rte.ie/'  # Replace with the RTÉ page or any target page
to_remove_ids = ['embedWrapper', 'panel-podcasts-we-love', 'panel-best-of-rte-player']
to_remove_classes = ['panel-heading', 'head-row', 'row buttonbar']
tags_to_extract = ['h3', 'h5']

# Fetch the HTML using Selenium
html_content = fetch_website_with_selenium(url)

if html_content:
    extracted_content = strip_html(html_content, to_remove_ids, to_remove_classes, tags_to_extract)
    indexed_data = add_reverse_column(extracted_content)
    # save_data_csv(indexed_data)

# %%
url = 'https://www.rte.ie/'  # Replace with the RTÉ page or any target page
to_remove_ids = ['embedWrapper', 'panel-podcasts-we-love', 'panel-best-of-rte-player']
to_remove_classes = ['panel-heading', 'head-row', 'row buttonbar']
tags_to_extract = ['h3', 'h5']

# Fetch the HTML using Selenium
html_content = fetch_website_with_selenium(url)

if html_content:
    extracted_content = strip_html(html_content, to_remove_ids, to_remove_classes, tags_to_extract)
    indexed_data = add_reverse_column(extracted_content)
    results_data = headline_analyser(indexed_data)
    # save_data_csv(indexed_data)

# %%
results_data = headline_analyser(indexed_data)

# %%
plot_sentiment_analysis(results_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plot_sentiment_analysis(results_data)
#
# File ~/Dev/Python/HeadLine_Analyser/utilities/sentiment_plot.py:41, in plot_sentiment_analysis(data)
#      39 plt.plot(df['Index'], df['VADER_MA_10'], label='VADER Compound (10% Moving Average)', color='lightgrey',linestyle='-', linewidth=2)
#      40 plt.plot(df['Index'], df['VADER_MA_25'], label='VADER Compound (25% Moving Average)', color='darkgrey', linestyle='--',  linewidth=2)
# ---> 41 plt.plot(df['Index'], df['VADER_MA_33'], label='VADER Compound (33% Moving Average)', color='black', linestyle='---', linewidth=2)
#      43 # Plot raw sentiment as a line graph
#      44 plt.plot(df['Index'], df['compound'], label='VADER Compound (Raw)', color='green', marker='o', alpha=0.6)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/pyplot.py:3708, in plot(scalex, scaley, data, *args, **kwargs)
#    3700 @_copy_docstring_and_deprecators(Axes.plot)
#    3701 def plot(
#    3702     *args: float | ArrayLike | str,
#    (...)
#    3706     **kwargs,
#    3707 ) -> list[Line2D]:
# -> 3708     return gca().plot(
#    3709         *args,
#    3710         scalex=scalex,
#    3711         scaley=scaley,
#    3712         **({"data": data} if data is not None else {}),
#    3713         **kwargs,
#    3714     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1536 """
#    1537 Plot y versus x as lines and/or markers.
#    1538
#    (...)
#    1776 (``'green'``) or hex strings (``'#008000'``).
#    1777 """
#    1778 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1779 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1780 for line in lines:
#    1781     self.add_line(line)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:296, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     294     this += args[0],
#     295     args = args[1:]
# --> 296 yield from self._plot_args(
#     297     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:534, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     532     return list(result)
#     533 else:
# --> 534     return [l[0] for l in result]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:534, in <listcomp>(.0)
#     532     return list(result)
#     533 else:
# --> 534     return [l[0] for l in result]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:527, in <genexpr>(.0)
#     522 else:
#     523     raise ValueError(
#     524         f"label must be scalar or have the same length as the input "
#     525         f"data, but found {len(label)} for {n_datasets} datasets.")
# --> 527 result = (make_artist(axes, x[:, j % ncx], y[:, j % ncy], kw,
#     528                       {**kwargs, 'label': label})
#     529           for j, label in enumerate(labels))
#     531 if return_kwargs:
#     532     return list(result)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:335, in _process_plot_var_args._makeline(self, axes, x, y, kw, kwargs)
#     333 kw = {**kw, **kwargs}  # Don't modify the original kw.
#     334 self._setdefaults(self._getdefaults(kw), kw)
# --> 335 seg = mlines.Line2D(x, y, **kw)
#     336 return seg, kw
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/lines.py:372, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     369 self._dash_pattern = (0, None)  # offset, dash (scaled by linewidth)
#     371 self.set_linewidth(linewidth)
# --> 372 self.set_linestyle(linestyle)
#     373 self.set_drawstyle(drawstyle)
#     375 self._color = None
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/lines.py:1177, in Line2D.set_linestyle(self, ls)
#    1175 if ls in [' ', '', 'none']:
#    1176     ls = 'None'
# -> 1177 _api.check_in_list([*self._lineStyles, *ls_mapper_r], ls=ls)
#    1178 if ls not in self._lineStyles:
#    1179     ls = ls_mapper_r[ls]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/_api/__init__.py:129, in check_in_list(values, _print_supported_values, **kwargs)
#     127 if _print_supported_values:
#     128     msg += f"; supported values are {', '.join(map(repr, values))}"
# --> 129 raise ValueError(msg)
#
# ValueError: '---' is not a valid value for ls; supported values are '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'
